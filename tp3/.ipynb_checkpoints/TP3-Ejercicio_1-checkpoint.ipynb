# %%
import sqlalchemy as alchemy
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date, Float, BigInteger

import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
# Conexion con postgres, creamos y nos conectamos a la bd pal tp3.
NOMBRE_BD = "tp3"
engine = alchemy.create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/'+NOMBRE_BD, echo=True)
try:
    conn = engine.connect()
    conn.execute("commit")
    conn.execute("create database " + NOMBRE_BD)
    conn.close()
except Exception as e:
    print str(e)

engine = alchemy.create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/'+"tp3", echo=True)
Base = declarative_base()
# Out:
#   File "<ipython-input-9-d1c70b3fc72c>", line 10
#     print str(e)
#             ^
# SyntaxError: invalid syntax

# %%
class Customer(Base):
    __tablename__ = 'Customer'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    address = Column(String)
    phone = Column(String)
    bday = Column(Date)
    gender = Column(String)
    
    #Para formateo de objeto
    def __repr___(self):
        return "<Customer(name='%s', address='%s', phone='%s', gender=%s')>"%(self.name, self.address, self.phone, self.gender)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-32d26ba42944> in <module>()
# ----> 1 class Customer(Base):
#       2     __tablename__ = 'Customer'
#       3
#       4     code = Column(Integer, primary_key=True)
#       5     name = Column(String)
#
# NameError: name 'Base' is not defined

# %%
class Timestamp(Base):
    __tablename__ = 'Timestamp'
    
    code = Column(Integer, primary_key=True)
    timestamp = Column(BigInteger)
    date = Column(Date)
    year = Column(Integer)

# %%
class ClaseVino(Base):
    __tablename__ = 'ClaseVino'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    region = Column(String)

# %%
class Wine(Base):
    __tablename__ = 'Wine'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    tipo = Column(String)
    vintage = Column(Integer)
    bottlePrice = Column(Float)
    casePrice = Column(Float)
    claseVino = Column(Integer)

# %%
class Order(Base):
    __tablename__ = 'Order'
    
    code = Column(Integer, primary_key=True)
    customer = Column(Integer)
    wine = Column(Integer)
    timeStamp = Column(Integer)
    nrBottles = Column(Integer)
    nrCases = Column(Integer)

# %%
Base.metadata.create_all(engine)
# Out:
# 2017-08-28 11:50:05,795 INFO sqlalchemy.engine.base.Engine select version()
# 2017-08-28 11:50:05,796 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,798 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-08-28 11:50:05,799 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,800 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 11:50:05,801 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,803 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 11:50:05,803 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,805 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-08-28 11:50:05,806 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,808 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,810 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}
# 2017-08-28 11:50:05,812 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,813 INFO sqlalchemy.engine.base.Engine {'name': u'Timestamp'}
# 2017-08-28 11:50:05,815 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,816 INFO sqlalchemy.engine.base.Engine {'name': u'Order'}
# 2017-08-28 11:50:05,818 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,818 INFO sqlalchemy.engine.base.Engine {'name': u'ClaseVino'}
# 2017-08-28 11:50:05,820 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,821 INFO sqlalchemy.engine.base.Engine {'name': u'Wine'}

# %%
# Probamos un ejemplo Customer
#cliente = Customer(name='Nicolas3', address='Julio A Roca', phone='41-(625)137-9314', bday='1968-05-20 16:31:20', gender='m')
#from sqlalchemy.orm import sessionmaker
#Session = sessionmaker(bind=engine)
#session = Session()
#session.add(cliente)
#session.commit()
#for instance in session.query(Customer).order_by(Customer.code):
 #   print(instance.name, instance.address)

# %%
datos_customer = 'data/MOCK_DATA-customer.csv'
datos_class = 'data/MOCK_DATA-class.csv'
datos_order = 'data/MOCK_DATA-order.csv'
datos_time = 'data/MOCK_DATA-time.csv'
datos_wine = 'data/MOCK_DATA-wine.csv'

df_customer = pd.DataFrame.from_csv(datos_customer,sep='\t')
df_class = pd.DataFrame.from_csv(datos_class,sep='\t')
df_order = pd.DataFrame.from_csv(datos_order,sep='\t')
df_time = pd.DataFrame.from_csv(datos_time,sep='\t')
df_wine = pd.DataFrame.from_csv(datos_wine,sep='\t')

# %%
# transforma los datos en sql, y los inserta.
df_customer.to_sql("Customer", con=engine, if_exists='replace')
df_class.to_sql("ClaseVino", con=engine, if_exists='replace')
df_order.to_sql("Order", con=engine, if_exists='replace')
datos_time.to_sql("Timestamp", con=engine, if_exists='replace')
datos_wine.to_sql("Wine", con=engine, if_exists='replace')
# Out:
# 2017-08-28 11:50:05,864 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,865 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}
# 2017-08-28 11:50:05,867 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:05,868 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}
# 2017-08-28 11:50:05,869 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:05,870 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 11:50:05,872 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in ('r', 'v', 'm', 'f')
#
# 2017-08-28 11:50:05,873 INFO sqlalchemy.engine.base.Engine {'table_name': u'Customer'}
# 2017-08-28 11:50:05,875 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid
#             FROM pg_catalog.pg_attribute a
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2017-08-28 11:50:05,876 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,881 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2017-08-28 11:50:05,882 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,884 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2017-08-28 11:50:05,885 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,888 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2017-08-28 11:50:05,890 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,892 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2017-08-28 11:50:05,893 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,896 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2017-08-28 11:50:05,897 INFO sqlalchemy.engine.base.Engine {'table': 16493}
# 2017-08-28 11:50:05,898 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2017-08-28 11:50:05,899 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,902 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2017-08-28 11:50:05,903 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,905 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.consrc as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2017-08-28 11:50:05,906 INFO sqlalchemy.engine.base.Engine {'table_oid': 16493}
# 2017-08-28 11:50:05,907 INFO sqlalchemy.engine.base.Engine
# DROP TABLE "Customer"
# 2017-08-28 11:50:05,908 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,911 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:05,919 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Customer" (
# 	"name,address,phone,bday,gender" TEXT
# )
#
#
# 2017-08-28 11:50:05,920 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,930 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:05,932 INFO sqlalchemy.engine.base.Engine CREATE INDEX "ix_Customer_name,address,phone,bday,gender" ON "Customer" ("name,address,phone,bday,gender")
# 2017-08-28 11:50:05,933 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:05,941 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:05,949 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-28 11:50:05,954 INFO sqlalchemy.engine.base.Engine INSERT INTO "Customer" ("name,address,phone,bday,gender") VALUES (%(name,address,phone,bday,gender)s)
# 2017-08-28 11:50:05,955 INFO sqlalchemy.engine.base.Engine ({'name,address,phone,bday,gender': 'Bonny,07324 Montana Way,41-(625)137-9314,1968-05-20 16:31:20,Female'}, {'name,address,phone,bday,gender': 'Brianna,839 Onsgard Court,359-(623)793-6068,1964-03-23 14:32:24,Female'}, {'name,address,phone,bday,gender': 'Shawna,520 Moose Avenue,970-(249)951-8657,1979-08-19 06:18:46,Female'}, {'name,address,phone,bday,gender': 'Allin,6 Harbort Street,996-(945)197-3282,1971-10-28 05:29:53,Male'}, {'name,address,phone,bday,gender': 'Ethelind,22 Dixon Point,63-(878)360-5280,1989-08-01 07:53:37,Female'}, {'name,address,phone,bday,gender': 'Rhianna,0 Ramsey Hill,86-(858)285-9284,1986-04-20 11:34:09,Female'}, {'name,address,phone,bday,gender': 'Julius,0271 Dahle Alley,86-(750)227-5599,1979-01-07 19:31:10,Male'}, {'name,address,phone,bday,gender': 'Thorin,16748 Hansons Drive,351-(237)922-4231,1989-02-10 04:05:22,Male'}  ... displaying 10 of 1000 total bound parameter sets ...  {'name,address,phone,bday,gender': 'Albrecht,3091 Carioca Road,86-(863)911-6146,1969-05-07 15:23:28,Male'}, {'name,address,phone,bday,gender': 'Justis,175 Laurel Place,7-(737)829-9661,2007-10-12 14:12:38,Male'})
# 2017-08-28 11:50:06,015 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,024 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:06,025 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 11:50:06,027 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:06,028 INFO sqlalchemy.engine.base.Engine {'name': u'ClaseVino'}
# 2017-08-28 11:50:06,029 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:06,030 INFO sqlalchemy.engine.base.Engine {'name': u'ClaseVino'}
# 2017-08-28 11:50:06,031 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:06,032 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 11:50:06,033 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in ('r', 'v', 'm', 'f')
#
# 2017-08-28 11:50:06,034 INFO sqlalchemy.engine.base.Engine {'table_name': u'ClaseVino'}
# 2017-08-28 11:50:06,035 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid
#             FROM pg_catalog.pg_attribute a
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2017-08-28 11:50:06,035 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,037 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2017-08-28 11:50:06,037 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,038 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2017-08-28 11:50:06,039 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,041 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2017-08-28 11:50:06,041 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,043 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2017-08-28 11:50:06,044 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,045 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2017-08-28 11:50:06,045 INFO sqlalchemy.engine.base.Engine {'table': 16473}
# 2017-08-28 11:50:06,047 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2017-08-28 11:50:06,047 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,049 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2017-08-28 11:50:06,050 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,051 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.consrc as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2017-08-28 11:50:06,052 INFO sqlalchemy.engine.base.Engine {'table_oid': 16473}
# 2017-08-28 11:50:06,053 INFO sqlalchemy.engine.base.Engine
# DROP TABLE "ClaseVino"
# 2017-08-28 11:50:06,054 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,055 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,062 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "ClaseVino" (
# 	"code,name,region" TEXT
# )
#
#
# 2017-08-28 11:50:06,063 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,071 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,073 INFO sqlalchemy.engine.base.Engine CREATE INDEX "ix_ClaseVino_code,name,region" ON "ClaseVino" ("code,name,region")
# 2017-08-28 11:50:06,073 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,076 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,079 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-28 11:50:06,083 INFO sqlalchemy.engine.base.Engine INSERT INTO "ClaseVino" ("code,name,region") VALUES (%(code,name,region)s)
# 2017-08-28 11:50:06,084 INFO sqlalchemy.engine.base.Engine ({'code,name,region': '1,"Duck, comb",Guyana'}, {'code,name,region': '2,Canadian river otter,Norway'}, {'code,name,region': '3,"Squirrel, palm",China'}, {'code,name,region': '4,Bee-eater (unidentified),Russia'}, {'code,name,region': '5,European badger,Greece'}, {'code,name,region': '6,"Colobus, white-mantled",Poland'}, {'code,name,region': '7,Egyptian viper,United States'}, {'code,name,region': '8,Arctic lemming,Bolivia'}  ... displaying 10 of 1000 total bound parameter sets ...  {'code,name,region': '999,"Goldeneye, barrows",Vietnam'}, {'code,name,region': '1000,Great white pelican,Indonesia'})
# 2017-08-28 11:50:06,138 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,159 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:06,160 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 11:50:06,163 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:06,164 INFO sqlalchemy.engine.base.Engine {'name': u'Order'}
# 2017-08-28 11:50:06,165 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 11:50:06,166 INFO sqlalchemy.engine.base.Engine {'name': u'Order'}
# 2017-08-28 11:50:06,168 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:06,168 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 11:50:06,170 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in ('r', 'v', 'm', 'f')
#
# 2017-08-28 11:50:06,171 INFO sqlalchemy.engine.base.Engine {'table_name': u'Order'}
# 2017-08-28 11:50:06,172 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid
#             FROM pg_catalog.pg_attribute a
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2017-08-28 11:50:06,173 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,174 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2017-08-28 11:50:06,175 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,177 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2017-08-28 11:50:06,178 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,180 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2017-08-28 11:50:06,180 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,182 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2017-08-28 11:50:06,183 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,185 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2017-08-28 11:50:06,185 INFO sqlalchemy.engine.base.Engine {'table': 16465}
# 2017-08-28 11:50:06,187 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2017-08-28 11:50:06,187 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,189 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2017-08-28 11:50:06,190 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,192 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.consrc as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2017-08-28 11:50:06,193 INFO sqlalchemy.engine.base.Engine {'table_oid': 16465}
# 2017-08-28 11:50:06,195 INFO sqlalchemy.engine.base.Engine
# DROP TABLE "Order"
# 2017-08-28 11:50:06,196 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,197 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,200 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Order" (
# 	"customer,wine,time,nrBottles,nrcases" TEXT
# )
#
#
# 2017-08-28 11:50:06,200 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,214 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,221 INFO sqlalchemy.engine.base.Engine CREATE INDEX "ix_Order_customer,wine,time,nrBottles,nrcases" ON "Order" ("customer,wine,time,nrBottles,nrcases")
# 2017-08-28 11:50:06,222 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 11:50:06,224 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,227 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-28 11:50:06,233 INFO sqlalchemy.engine.base.Engine INSERT INTO "Order" ("customer,wine,time,nrBottles,nrcases") VALUES (%(customer,wine,time,nrBottles,nrcases)s)
# 2017-08-28 11:50:06,234 INFO sqlalchemy.engine.base.Engine ({'customer,wine,time,nrBottles,nrcases': '355,682,441,93,2'}, {'customer,wine,time,nrBottles,nrcases': '163,336,296,95,2'}, {'customer,wine,time,nrBottles,nrcases': '584,352,72,73,2'}, {'customer,wine,time,nrBottles,nrcases': '965,10,715,33,2'}, {'customer,wine,time,nrBottles,nrcases': '465,149,803,60,5'}, {'customer,wine,time,nrBottles,nrcases': '936,205,960,95,1'}, {'customer,wine,time,nrBottles,nrcases': '806,840,230,15,5'}, {'customer,wine,time,nrBottles,nrcases': '560,555,608,77,7'}  ... displaying 10 of 1000 total bound parameter sets ...  {'customer,wine,time,nrBottles,nrcases': '155,587,662,82,8'}, {'customer,wine,time,nrBottles,nrcases': '346,344,954,91,4'})
# 2017-08-28 11:50:06,290 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 11:50:06,309 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 11:50:06,309 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-20ca041f2c4b> in <module>()
#       3 df_class.to_sql("ClaseVino", con=engine, if_exists='replace')
#       4 df_order.to_sql("Order", con=engine, if_exists='replace')
# ----> 5 datos_time.to_sql("Timestamp", con=engine, if_exists='replace')
#       6 datos_wine.to_sql("Wine", con=engine, if_exists='replace')
#
# AttributeError: 'str' object has no attribute 'to_sql'

# %%
#location2 = 'data/MOCK_DATA-wine.csv'
#df2 = pd.read_csv(location2)
#df.to_sql("Customer", con=engine, if_exists='replace')

# %%
#print 2

# %%
#df2
