# %%
import sqlalchemy as alchemy
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date, Float, BigInteger

import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
# Conexion con postgres, creamos y nos conectamos a la bd pal tp3.
NOMBRE_BD = "tp3"
engine = alchemy.create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432', echo=True)
try:
    conn = engine.connect()
    conn.execute("commit")
    conn.execute("create database " + NOMBRE_BD)
    conn.close()
except Exception as e:
    print str(e)
engine = alchemy.create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/'+NOMBRE_BD, echo=True)
Base = declarative_base()
# Out:
# 2017-08-28 00:51:15,644 INFO sqlalchemy.engine.base.Engine select version()
# 2017-08-28 00:51:15,646 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,662 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-08-28 00:51:15,664 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,680 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 00:51:15,682 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,757 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 00:51:15,758 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,764 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-08-28 00:51:15,766 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,770 INFO sqlalchemy.engine.base.Engine commit
# 2017-08-28 00:51:15,772 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,775 INFO sqlalchemy.engine.base.Engine create database tp3
# 2017-08-28 00:51:15,776 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:15,798 INFO sqlalchemy.engine.base.Engine ROLLBACK
# (psycopg2.ProgrammingError) database "tp3" already exists
#  [SQL: 'create database tp3']

# %%
class Customer(Base):
    __tablename__ = 'Customer'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    address = Column(String)
    phone = Column(String)
    bday = Column(Date)
    gender = Column(String)
    
    #Para formateo de objeto
    def __repr___(self):
        return "<Customer(name='%s', address='%s', phone='%s', gender=%s')>"%(self.name, self.address, self.phone, self.gender)

# %%
class Timestamp(Base):
    __tablename__ = 'Timestamp'
    
    code = Column(Integer, primary_key=True)
    timestamp = Column(BigInteger)
    date = Column(Date)
    year = Column(Integer)

# %%
class ClaseVino(Base):
    __tablename__ = 'ClaseVino'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    region = Column(String)

# %%
class Wine(Base):
    __tablename__ = 'Wine'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    tipo = Column(String)
    vintage = Column(Integer)
    bottlePrice = Column(Float)
    casePrice = Column(Float)
    claseVino = Column(Integer)

# %%
class Order(Base):
    __tablename__ = 'Order'
    
    code = Column(Integer, primary_key=True)
    customer = Column(Integer)
    wine = Column(Integer)
    timeStamp = Column(Integer)
    nrBottles = Column(Integer)
    nrCases = Column(Integer)

# %%
Base.metadata.create_all(engine)
# Out:
# 2017-08-28 00:51:31,178 INFO sqlalchemy.engine.base.Engine select version()
# 2017-08-28 00:51:31,181 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:31,184 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-08-28 00:51:31,185 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:31,193 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 00:51:31,195 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:31,202 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-08-28 00:51:31,204 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:31,210 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-08-28 00:51:31,211 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:31,215 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 00:51:31,218 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}

# %%
# Probamos un ejemplo Customer
cliente = Customer(name='Nicolas3', address='Julio A Roca', phone='41-(625)137-9314', bday='1968-05-20 16:31:20', gender='m')
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()
session.add(cliente)
session.commit()
for instance in session.query(Customer).order_by(Customer.code):
    print(instance.name, instance.address)
# Out:
# 2017-08-28 00:51:39,431 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-28 00:51:39,435 INFO sqlalchemy.engine.base.Engine INSERT INTO "Customer" (name, address, phone, bday, gender) VALUES (%(name)s, %(address)s, %(phone)s, %(bday)s, %(gender)s) RETURNING "Customer".code
# 2017-08-28 00:51:39,438 INFO sqlalchemy.engine.base.Engine {'bday': '1968-05-20 16:31:20', 'phone': '41-(625)137-9314', 'gender': 'm', 'name': 'Nicolas3', 'address': 'Julio A Roca'}
# 2017-08-28 00:51:39,444 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-08-28 00:51:39,503 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-28 00:51:39,520 INFO sqlalchemy.engine.base.Engine SELECT "Customer".code AS "Customer_code", "Customer".name AS "Customer_name", "Customer".address AS "Customer_address", "Customer".phone AS "Customer_phone", "Customer".bday AS "Customer_bday", "Customer".gender AS "Customer_gender"
# FROM "Customer" ORDER BY "Customer".code
# 2017-08-28 00:51:39,529 INFO sqlalchemy.engine.base.Engine {}
# (u'Nicolas', u'Julio A Roca')
# (u'Nicolas', u'Julio A Roca')
# (u'Nicolas', u'Julio A Roca')
# (u'Nicolas', u'Julio A Roca')
# (u'Nicolas', u'Julio A Roca')
# (u'Nicolas2', u'Julio A Roca')
# (u'Nicolas3', u'Julio A Roca')
# (u'Nicolas3', u'Julio A Roca')
# (u'Nicolas3', u'Julio A Roca')
# (u'Nicolas3', u'Julio A Roca')

# %%
datos_customer = 'data/MOCK_DATA-customer.csv'
datos_class = 'data/MOCK_DATA-class.csv'
datos_order = 'data/MOCK_DATA-order.csv'
datos_time = 'data/MOCK_DATA-time.csv'
datos_wine = 'data/MOCK_DATA-wine.csv'

df_customer = pd.read_csv(datos_customer)
df_customer
# Out:
#            name                     address              phone  \
# 0         Bonny           07324 Montana Way   41-(625)137-9314
# 1       Brianna           839 Onsgard Court  359-(623)793-6068
# 2        Shawna            520 Moose Avenue  970-(249)951-8657
# 3         Allin            6 Harbort Street  996-(945)197-3282
# 4      Ethelind              22 Dixon Point   63-(878)360-5280
# 5       Rhianna               0 Ramsey Hill   86-(858)285-9284
# 6        Julius            0271 Dahle Alley   86-(750)227-5599
# 7        Thorin         16748 Hansons Drive  351-(237)922-4231
# 8        Bondon     32760 Browning Crossing    1-(182)566-6482
# 9      Hortense  02000 Glacier Hill Parkway   62-(697)825-8605
# 10        Willy         869 Bartillon Plaza    7-(367)235-5972
# 11         Dunn        27 Crownhardt Circle   62-(370)196-0774
# 12         Mylo        08729 Paget Crossing  380-(636)202-0818
# 13       Kellia       1256 American Terrace  254-(824)749-8493
# 14     Reinhold             24 Fulton Alley   65-(859)351-8266
# 15          Dar   280 Norway Maple Crossing   52-(684)311-8999
# 16     Waldemar               1 Haas Center  242-(860)916-7147
# 17      Merrick           715 Bartelt Court   46-(980)817-5014
# 18        Nicky             5 Jenna Terrace  598-(160)637-5452
# 19        Bucky    7617 Cottonwood Crossing   58-(125)198-3239
# 20         Bary    975 Buena Vista Crossing   86-(885)902-4229
# 21       Susana            88176 Spohn Pass  972-(838)115-3370
# 22        Lynne         932 Graedel Parkway   86-(607)167-2462
# 23       Kesley          709 Prentice Trail   66-(149)611-3081
# 24      Brandtr      85758 Colorado Parkway   63-(926)960-3097
# 25        Adham         77748 Rigney Avenue   86-(506)839-5544
# 26         Neil          53484 Walton Alley  420-(783)261-0320
# 27       Mischa        3699 Farragut Avenue   86-(369)187-5035
# 28        Caril            55 Maywood Drive   86-(892)950-5422
# 29         Suki       2968 Browning Terrace  966-(244)917-6545
# 974  1970-12-22 05:59:31    Male
# 975  2002-02-20 20:27:57  Female
# 976  2000-05-11 01:45:01  Female
# 977  2001-10-19 10:42:24    Male
# 978  1996-09-26 13:01:30    Male
# 979  1969-01-22 07:21:22  Female
# 980  2007-03-31 20:11:50    Male
# 981  1986-02-11 08:27:05    Male
# 982  1988-01-24 03:34:00    Male
# 983  1968-09-09 06:43:21    Male
# 984  1972-03-23 10:32:59    Male
# 985  1994-01-02 09:27:57  Female
# 986  1957-05-25 12:29:59    Male
# 987  1993-11-19 03:34:07    Male
# 988  2004-02-09 21:38:50    Male
# 989  1982-05-13 13:35:06  Female
# 990  1976-05-29 12:09:11    Male
# 991  1981-03-28 22:22:46  Female
# 992  1971-01-17 05:45:46    Male
# 993  1988-06-08 17:39:32    Male
# 994  1992-05-20 16:02:56    Male
# 995  2009-01-14 21:19:06  Female
# 996  1978-07-30 19:07:43    Male
# 997  1961-11-20 23:09:57  Female
# 998  1969-05-07 15:23:28    Male
# 999  2007-10-12 14:12:38    Male
#
# [1000 rows x 5 columns]

# %%
# transforma los datos en sql, y los inserta.
df_customer.to_sql("Customer", con=engine, if_exists='replace')
# Out:
# 2017-08-28 00:51:56,649 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 00:51:56,650 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}
# 2017-08-28 00:51:56,659 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-28 00:51:56,660 INFO sqlalchemy.engine.base.Engine {'name': u'Customer'}
# 2017-08-28 00:51:56,668 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-28 00:51:56,670 INFO sqlalchemy.engine.base.Engine {'schema': u'public'}
# 2017-08-28 00:51:56,680 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in ('r', 'v', 'm', 'f')
#
# 2017-08-28 00:51:56,690 INFO sqlalchemy.engine.base.Engine {'table_name': u'Customer'}
# 2017-08-28 00:51:56,693 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid
#             FROM pg_catalog.pg_attribute a
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2017-08-28 00:51:56,695 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,699 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2017-08-28 00:51:56,701 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:56,720 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2017-08-28 00:51:56,721 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-28 00:51:56,727 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2017-08-28 00:51:56,728 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,731 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2017-08-28 00:51:56,732 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,737 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2017-08-28 00:51:56,739 INFO sqlalchemy.engine.base.Engine {'table': 16426}
# 2017-08-28 00:51:56,742 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2017-08-28 00:51:56,743 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,747 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2017-08-28 00:51:56,749 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,751 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.consrc as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2017-08-28 00:51:56,752 INFO sqlalchemy.engine.base.Engine {'table_oid': 16426}
# 2017-08-28 00:51:56,754 INFO sqlalchemy.engine.base.Engine
# DROP TABLE "Customer"
# 2017-08-28 00:51:56,763 INFO sqlalchemy.engine.base.Engine {}

# %%
location2 = 'data/MOCK_DATA-wine.csv'
df2 = pd.read_csv(location2)
df.to_sql("Customer", con=engine, if_exists='replace')

# %%
print 2

# %%
df2
