# %%
import sqlalchemy as alchemy
alchemy.__version__
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/tp3', echo=True)
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date
Base = declarative_base()

# %%
class Customer(Base):
    __tablename__ = 'Customer'
    
    code = Column(Integer, primary_key=True)
    name = Column(String)
    address = Column(String)
    phone = Column(String)
    bday = Column(Date)
    gender = Column(String)
    
    #Para formateo de objeto
    def __repr___(self):
        return "<Customer(name='%s', address='%s', phone='%s', gender=%s')>"%(self.name, self.address, self.phone, self.gender)

# %%
Base.metadata.create_all(engine)
# Out:
# 2017-08-23 17:38:08,489 INFO sqlalchemy.engine.base.Engine select version()
# 2017-08-23 17:38:08,495 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-23 17:38:08,499 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-08-23 17:38:08,501 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-23 17:38:08,504 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-08-23 17:38:08,507 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-23 17:38:08,516 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-08-23 17:38:08,522 INFO sqlalchemy.engine.base.Engine {}
# 2017-08-23 17:38:08,527 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-08-23 17:38:08,532 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
cliente = Customer(name='Nicolas', address='Julio A Roca', phone='123456789', bday='2017/08/22', gender='m')

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)

# %%
session = Session()

# %%
session.add(cliente)

# %%
session.commit()
# Out:
# 2017-08-23 17:45:16,878 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-23 17:45:16,881 INFO sqlalchemy.engine.base.Engine INSERT INTO "Customer" (name, address, phone, bday, gender) VALUES (%(name)s, %(address)s, %(phone)s, %(bday)s, %(gender)s) RETURNING "Customer".code
# 2017-08-23 17:45:16,883 INFO sqlalchemy.engine.base.Engine {'bday': '2017/08/22', 'gender': 'm', 'address': 'Julio A Roca', 'name': 'Nicolas', 'phone': '123456789'}
# 2017-08-23 17:45:16,892 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
for instance in session.query(Customer).order_by(Customer.code):
    print(instance.name, instance.address)
# Out:
# 2017-08-23 17:45:19,641 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-08-23 17:45:19,647 INFO sqlalchemy.engine.base.Engine SELECT "Customer".code AS "Customer_code", "Customer".name AS "Customer_name", "Customer".address AS "Customer_address", "Customer".phone AS "Customer_phone", "Customer".bday AS "Customer_bday", "Customer".gender AS "Customer_gender"
# FROM "Customer" ORDER BY "Customer".code
# 2017-08-23 17:45:19,654 INFO sqlalchemy.engine.base.Engine {}
# (u'Dami\xe1n', u'Julio A Roca')
# (u'Nicolas', u'Julio A Roca')

# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 2.7.12 (default, Nov 19 2016, 06:48:10)
# [GCC 5.4.0 20160609]
# Pandas version 0.20.3
# Matplotlib version 2.0.0

# %%
location = r'C:\Users\fdman\Desktop/MOCK_DATA-customer.csv'
df = pd.read_csv(location)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-49-21ce138ef3d3> in <module>()
#       1 location = r'C:\Users\fdman\Desktop/MOCK_DATA-customer.csv'
# ----> 2 df = pd.read_csv(location)
#
# ...

# %%
df
# Out:
#            name                     address              phone  \
# 0         Bonny           07324 Montana Way   41-(625)137-9314
# 1       Brianna           839 Onsgard Court  359-(623)793-6068
# 2        Shawna            520 Moose Avenue  970-(249)951-8657
# 3         Allin            6 Harbort Street  996-(945)197-3282
# 4      Ethelind              22 Dixon Point   63-(878)360-5280
# 5       Rhianna               0 Ramsey Hill   86-(858)285-9284
# 6        Julius            0271 Dahle Alley   86-(750)227-5599
# 7        Thorin         16748 Hansons Drive  351-(237)922-4231
# 8        Bondon     32760 Browning Crossing    1-(182)566-6482
# 9      Hortense  02000 Glacier Hill Parkway   62-(697)825-8605
# 10        Willy         869 Bartillon Plaza    7-(367)235-5972
# 11         Dunn        27 Crownhardt Circle   62-(370)196-0774
# 12         Mylo        08729 Paget Crossing  380-(636)202-0818
# 13       Kellia       1256 American Terrace  254-(824)749-8493
# ...

# %%
df.to_sql("Customer", engine, None, None, None)
# Out:
# 2017-08-22 20:33:01,823 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-22 20:33:01,825 INFO sqlalchemy.engine.base.Engine {'name': 'Customer'}
# 2017-08-22 20:33:01,832 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-08-22 20:33:01,833 INFO sqlalchemy.engine.base.Engine {'name': 'Customer'}
# 2017-08-22 20:33:01,837 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# 2017-08-22 20:33:01,838 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2017-08-22 20:33:01,888 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
# ...

# %%
location2 = r'C:\Users\fdman\Desktop/MOCK_DATA-wine.csv'
df2 = pd.read_csv(location2)

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d4a59695a920> in <module>()
# ----> 1 df2
#
# NameError: name 'df2' is not defined
